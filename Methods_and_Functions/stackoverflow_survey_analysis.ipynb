# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
survey = pd.read_csv('../resources/survey_results_public.csv',index = None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4868f250a242> in <module>
# ----> 1 survey = pd.read_csv('../resources/survey_results_public.csv',index = None)
#
# TypeError: parser_f() got an unexpected keyword argument 'index'

# %%
survey.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
survey.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
survey.set_index('Respondent',inplace=True)

# %%
survey
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
survey.shape
# Out:
# (64461, 60)

# %%
survey.size
# Out:
# 3867660

# %%
survey.ndim
# Out:
# 2

# %% [markdown]
# ## Finding out the percentage of people who filled the survey completely,without leaving anything

# %%
new_survey = survey.dropna()

# %%
new_survey1 = survey.dropna(axis = 0)

# %%
new_survey.shape
# Out:
# (4213, 60)

# %%
new_survey1.shape
# Out:
# (4213, 60)

# %%
new_survey.size
# Out:
# 252780

# %%
new_survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
completed_survey = new_survey['Country'].value_counts().sort_values(ascending= False).head(10)
completed_survey
# Out:
# United States     1089
# United Kingdom     324
# Germany            266
# India              229
# Brazil             176
# Canada             165
# France             128
# Australia          119
# Netherlands        115
# Italy               84
# Name: Country, dtype: int64

# %%
total = survey['Country'].value_counts()
total
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Micronesia, Federated States of...        1
# North Korea                               1
# Gabon                                     1
# Fiji                                      1
# Grenada                                   1
# Name: Country, Length: 183, dtype: int64

# %%
completed_country = [country for country in completed_survey.index]
completed_country
# Out:
# ['United States',
#  'United Kingdom',
#  'Germany',
#  'India',
#  'Brazil',
#  'Canada',
#  'France',
#  'Australia',
#  'Netherlands',
#  'Italy']

# %%
total.loc['Italy']
# Out:
# 1117

# %%
total_per_country = []
for item in completed_country:
    total_per_country.append(total.loc[item])
total_per_country
# Out:
# [12469, 3896, 3890, 8403, 1818, 2191, 1898, 1208, 1343, 1117]

# %%
percentage = pd.DataFrame()
percentage['Country'] = completed_country
percentage['Total'] = total_per_country
percentage['Completed'] = [item for item in completed_survey]
percentage.set_index('Country',inplace = True)

percentage
# Out:
#                 Total  Completed
# Country
# United States   12469       1089
# United Kingdom   3896        324
# Germany          3890        266
# India            8403        229
# Brazil           1818        176
# Canada           2191        165
# France           1898        128
# Australia        1208        119
# Netherlands      1343        115
# Italy            1117         84

# %%
percentage['%'] = round(percentage['Completed'] / percentage['Total'] *100,2)
percentage
# Out:
#                 Total  Completed     %
# Country
# United States   12469       1089  8.73
# United Kingdom   3896        324  8.32
# Germany          3890        266  6.84
# India            8403        229  2.73
# Brazil           1818        176  9.68
# Canada           2191        165  7.53
# France           1898        128  6.74
# Australia        1208        119  9.85
# Netherlands      1343        115  8.56
# Italy            1117         84  7.52

# %%
1089/12469 * 100
# Out:
# 8.733659475499238

# %%
percentage.sort_values(by='%',ascending = False)
# Out:
#                 Total  Completed     %
# Country
# Australia        1208        119  9.85
# Brazil           1818        176  9.68
# United States   12469       1089  8.73
# Netherlands      1343        115  8.56
# United Kingdom   3896        324  8.32
# Canada           2191        165  7.53
# Italy            1117         84  7.52
# Germany          3890        266  6.84
# France           1898        128  6.74
# India            8403        229  2.73
